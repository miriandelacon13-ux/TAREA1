# %% [markdown]
# # Tarea 1 - Pandas
#
# ## Análisis de los ingresos presupuestales de los Organismos Públicos Descentralizados del Perú - 2025

# %%
import pandas as pd

# %% [markdown]
# Importé la librería Pandas porque permite trabajar con bases de datos en Python, facilitando su carga, revisión, limpieza y análisis.

# %%
df = pd.read_csv("2025-Ingresos-OPDS.csv")

# %% [markdown]
# Cargué la base de datos de ingresos presupuestales del año 2025 y la guardé en un DataFrame llamado `df`, que será la base principal del análisis.

# %%
df.head()
# Out:
#    ANO_DOC  MES_DOC  GRUPO_ENTIDAD  \
# 0     2025        8             17
# 1     2025       11             17
# 2     2025        5             17
# 3     2025        3             17
# 4     2025        1             17
#
#                               GRUPO_ENTIDAD_NOMBRE  SEC_EJEC  EJECUTORA  \
# 0  ORGANISMOS PUBLICOS DESCENTRALIZADOS REGIONALES    500108          0
# 1  ORGANISMOS PUBLICOS DESCENTRALIZADOS REGIONALES    500108          0
# 2  ORGANISMOS PUBLICOS DESCENTRALIZADOS REGIONALES    500108          0
# 3  ORGANISMOS PUBLICOS DESCENTRALIZADOS REGIONALES    500108          0
# 4  ORGANISMOS PUBLICOS DESCENTRALIZADOS REGIONALES    500108          0
#
#                                     EJECUTORA_NOMBRE  DEPARTAMENTO_EJECUTORA  \
# 0  COMITE DE ADMINISTRACIÓN DE LA ZONA FRANCA Y Z...                      23
# 1  COMITE DE ADMINISTRACIÓN DE LA ZONA FRANCA Y Z...                      23
# 2  COMITE DE ADMINISTRACIÓN DE LA ZONA FRANCA Y Z...                      23
# 3  COMITE DE ADMINISTRACIÓN DE LA ZONA FRANCA Y Z...                      23
# 4  COMITE DE ADMINISTRACION DE LA ZONA FRANCA Y Z...                      23
#
#   DEPARTAMENTO_EJECUTORA_NOMBRE  PROVINCIA_EJECUTORA  ...  SUBGENERICA_NOMBRE  \
# 0                         TACNA                    1  ...     VENTA DE BIENES
# 1                         TACNA                    1  ...  VENTA DE SERVICIOS
# 2                         TACNA                    1  ...  VENTA DE SERVICIOS
# 3                         TACNA                    1  ...  VENTA DE SERVICIOS
# 4                         TACNA                    1  ...   INGRESOS DIVERSOS
#
#    SUBGENERICA_DET                      SUBGENERICA_DET_NOMBRE  ESPECIFICA  \
# 0                3                VENTA DE PRODUCTOS MINERALES           1
# 1                2    SERVICIOS DE TRANSPORTE Y COMUNICACIONES           1
# 2                2    SERVICIOS DE TRANSPORTE Y COMUNICACIONES           2
# 3                9  OTROS INGRESOS POR PRESTACION DE SERVICIOS           1
# 4                1                           INGRESOS DIVERSOS           4
#
#                             ESPECIFICA_NOMBRE  ESPECIFICA_DET  \
# 0                VENTA DE PRODUCTOS MINERALES               1
# 1                     SERVICIOS DE TRANSPORTE               2
# 2                 SERVICIOS DE COMUNICACIONES              99
# 3  SERVICIOS POR ADMINISTRACION Y RECAUDACION               3
# 4                     OTROS INGRESOS DIVERSOS              99
#
#                ESPECIFICA_DET_NOMBRE  MONTO_PIA MONTO_PIM  MONTO_RECAUDADO
# 0                      VENTA DE AGUA          0         0          7929.34
# 1            SERVICIOS DE INSPECCION          0         0             0.00
# 2  OTROS SERVICIOS DE COMUNICACIONES          0         0         19988.99
# 3        SERVICIOS DE ADMINISTRACION          0         0          2603.80
# 4            OTROS INGRESOS DIVERSOS          0         0          7995.52
#
# [5 rows x 32 columns]

# %% [markdown]
# Mostré las primeras cinco filas para conocer cómo está organizada la base y observar algunas de las variables que contiene.
